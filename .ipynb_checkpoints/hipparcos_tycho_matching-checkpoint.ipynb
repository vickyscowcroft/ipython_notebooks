# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import notebook
E = notebook.nbextensions.EnableNBExtensionApp()
E.enable_nbextension('usability/python-markdown/main')
import pandas as pd
from scipy.optimize import curve_fit
import markdown
import sys
sys.path.append('/Users/vs/Dropbox/Python')
from astropy.table import Table
from astropy import units as u
from astropy.coordinates import SkyCoord
import seaborn as sns

bigfontsize=20
labelfontsize=16
tickfontsize=16
sns.set_context('talk')
plt.rcParams.update({'font.size': bigfontsize,
                     'axes.labelsize':labelfontsize,
                     'xtick.labelsize':tickfontsize,
                     'ytick.labelsize':tickfontsize,
                     'legend.fontsize':tickfontsize,
                     })

# %% [markdown]
# # TODO - Check which of these are Tycho and which are Hipparcos
#
# # Matching the Hipparcos and Tycho catalogues to the SMHASH/CRRP observations

# %% [markdown]
# ## Hipparcos RR Lyrae
#
# * Hipparcos main catalogue - http://vizier.u-strasbg.fr/viz-bin/VizieR-3?-source=I/239/hip_main
# * Hipparcos variability annex - http://vizier.u-strasbg.fr/viz-bin/VizieR-3?-source=I/239/hip_va_1
#
# To get the positions of the RRL out of this catalogue need to match the two up. The variability annex doesn't have RA, Dec.
#
# Can match the two catalogues using TAPVizier
# * Uses ADQL - Like SQL
# * Need to match on HID
# * Want HID, RA, Dec, Type, Period

# %% [markdown]
# ADQL query to match the catalogues:
#
# ```sql
# SELECT "I/239/hip_main".HIP, "RA(ICRS)", "DE(ICRS)", "VarType", "VarName", "I/239/hip_va_1"."Period"
# FROM "I/239/hip_main", "I/239/hip_va_1"
# WHERE "I/239/hip_main".HIP="I/239/hip_va_1".HIP AND "I/239/hip_va_1".VarType LIKE 'RR%'
# ```

# %% [markdown]
# Output saved to ~/Dropbox/SMHASH/Hipparcos_Comparison/Hipparcos_RRL

# %% [markdown]
# ## Tycho RR Lyrae
#
# Maintz (2005) claims many IDs of RRL in Tycho 2 catalogue are wrong. Match that catalogue with Tycho 2 to get list of RRL that appear in Tycho.
#
# Maintz catalogue: J/A+A/442/381/table1
#
# Use Cat='T' to select those in Tycho
#
# Output saved to ~/Dropbox/SMHASH/Hipparcos_Comparison/Tycho_RRL

# %% [markdown]
# ## Find the unique stars
#
# Some of these stars are in both catalogues. Need to filter the catalogues so it's a unique list.

# %%
hipparcos = pd.read_csv("Hipparcos_RRL", sep='|')
hipparcos.rename(columns=lambda x: x.strip(), inplace=True) ## Stripping the whitespace out of the column names
hipparcos.rename(columns = {'RA(ICRS)':'RA', 'DE(ICRS)':'Dec'}, inplace=True) ## Getting rid of the (ICRS)
hipparcos = hipparcos.assign(RRName = lambda x: (x.VarName.str.replace('_', '')))
hipparcos = hipparcos.assign(Catname = 'Hipparcos')

tycho = pd.read_csv("Tycho_RRL", sep='|')
tycho.rename(columns=lambda x: x.strip(), inplace=True)
tycho.rename(columns = {'RAJ2000' : 'RA', 'DEJ2000' : 'Dec', 'VType' : 'VarType'}, inplace=True)
tycho = tycho.assign(RRName = lambda x: (x.Star.str.replace(' ', '')))
tycho = tycho.assign(Catname = 'Tycho')

# %%
hipparcos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 185
# Data columns (total 8 columns):
# HIP        186 non-null int64
# RA         186 non-null float64
# Dec        186 non-null float64
# VarType    186 non-null object
# VarName    186 non-null object
# Period     186 non-null object
# RRName     186 non-null object
# Catname    186 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 13.1+ KB

# %%
tycho.head()
# Out:
#            RA        Dec       Star VarType    Period RRName Catname
# 0  353.002946  35.196908  DM And      RRab   0.630389  DMAnd   Tycho
# 1   16.294612  34.218400  DR And      RRab   0.563118  DRAnd   Tycho
# 2    5.184192  40.828000  OV And      RRab   0.470581  OVAnd   Tycho
# 3  245.214571 -71.671039  BS Aps      RRab   0.582556  BSAps   Tycho
# 4  330.481325  -5.600711  TZ Aqr      RRab   0.571194  TZAqr   Tycho

# %% [markdown]
# Match the two catalogues to see which stars appear in both

# %%
hipparcos.head()
# Out:
#     HIP        RA        Dec  VarType    VarName     Period    RRName  \
# 0   226  0.700312 -24.945255  RRAB     RU_Scl     0.4933470  RUScl
# 1   320  1.021268 -16.997641  RRAB     UU_Cet     0.6060830  UUCet
# 2  1222  3.809727  60.340474  RRAB     V363_Cas   0.5465650  V363Cas
# 3  1878  5.929558  29.401053  RRAB     SW_And     0.4422620  SWAnd
# 4  2655  8.409568 -15.487302  RRAB     RX_Cet     0.5736850  RXCet
#
#      Catname
# 0  Hipparcos
# 1  Hipparcos
# 2  Hipparcos
# 3  Hipparcos
# 4  Hipparcos

# %%
matched = pd.merge(left=hipparcos, right=tycho, how='left', left_on='RRName', right_on='RRName')

# %%
len(tycho) + len(hipparcos)
# Out:
# 295

# %% [markdown]
# **None of the Tycho RRL appear in the Hipparcos RRL catalogue if you match by name. Might miss a couple that way, but this is just an estimate. I can do a proper calculation if we need it.**

# %% [markdown]
# # Total number of Hipparcos and Tycho RR Lyrae variables = 295#

# %% [markdown]
# # Matching the catalogue to the Spitzer observations

# %%
hiptyc = pd.concat([hipparcos, tycho], axis=0)

# %%
hiptyc.head()
# Out:
#      Catname        Dec   HIP     Period        RA    RRName Star    VarName  \
# 0  Hipparcos -24.945255   226  0.4933470  0.700312  RUScl     NaN  RU_Scl
# 1  Hipparcos -16.997641   320  0.6060830  1.021268  UUCet     NaN  UU_Cet
# 2  Hipparcos  60.340474  1222  0.5465650  3.809727  V363Cas   NaN  V363_Cas
# 3  Hipparcos  29.401053  1878  0.4422620  5.929558  SWAnd     NaN  SW_And
# 4  Hipparcos -15.487302  2655  0.5736850  8.409568  RXCet     NaN  RX_Cet
#
#    VarType
# 0  RRAB
# 1  RRAB
# 2  RRAB
# 3  RRAB
# 4  RRAB

# %% [markdown]
# Combined data set is now **hiptyc** data frame.
#
# Useful columns are RA, Dec, RRName, VarType, Period
#
# Star, VarName, HIP not defined for all stars.

# %% [markdown]
# # Searching for the HipTyc objects in the Spitzer Heritage Archive
# * Want to check if we observed thses objects as part of CRRP or SMHASH
# * Can check for two things:
#   1. Have they been observed at all by Spitzer?
#   2. Have they been observed specifically by us?

# %% [markdown]
# Have the HipTyc stars been observed at all by Spitzer?
# -----------------------------------------------------------------------
#
# * SHA can take a list as input:
#   1. Send the catalogue to an output text file
#   2. Give this as input to the SHA
#   3. Set a small search radius (1 arcmin - want to make sure they're on the frame)
#   4. ???
#   5. PROFIT

# %%
hiptyc.to_csv('hiptyc.csv', columns=('RRName', 'RA', 'Dec', 'Catname'), header=('NAME', 'RA', 'DEC', 'CATNAME'), index=False)

# %%
tycho.to_csv('tycho.csv', columns=('RRName', 'RA', 'Dec'), header=('NAME', 'RA', 'DEC'), index=False)

# %% [markdown]
# Used this as input to the SHA search with 1 arcmin search radius. Saved results to hiptyc_obs_by_spitzer.ipac
#
# Now going to search this to find unique targets.

# %%
spitzer_ipac = Table.read('hiptyc_obs_by_spitzer.ipac', format='ipac')

# %%
spitzer = spitzer_ipac.to_pandas()

# %%
spitzer.head()
# Out:
#                     Search_Tgt Target_name  RA(J2000)  Dec(J2000)  \
# 0  0h02m48.0749s 0h02m48.0749s      RU_Scl        0.7  -24.945278
# 1  0h02m48.0749s 0h02m48.0749s      RU_Scl        0.7  -24.945278
# 2  0h02m48.0749s 0h02m48.0749s      RU_Scl        0.7  -24.945278
# 3  0h02m48.0749s 0h02m48.0749s      RU_Scl        0.7  -24.945278
# 4  0h02m48.0749s 0h02m48.0749s      RU_Scl        0.7  -24.945278
#
#   Instrument/Mode    AORKEY      AOR_label  progid               PI
# 0     IRAC Map PC  47289600  RU_Scl_epoch5   90002  Freedman, Wendy
# 1     IRAC Map PC  47291136  RU_Scl_epoch2   90002  Freedman, Wendy
# 2     IRAC Map PC  47288576  RU_Scl_epoch7   90002  Freedman, Wendy
# 3     IRAC Map PC  47290112  RU_Scl_epoch4   90002  Freedman, Wendy
# 4     IRAC Map PC  47290624  RU_Scl_epoch3   90002  Freedman, Wendy

# %% [markdown]
# Now have the Spitzer search results in a pandas dataFrame!

# %% [markdown]
# Each HipTyc RRL can be matched to multiple observations. The matched HipTyc star is given in Search_Tgt
#
# * Need to find how many unique values there are in Search_Tgt column
# * Then see who observed them
#  - How many are observed by us (i.e. have time series data)
#  - How many were observed by other programs (may be single epoch)
#  - Which ones are both? Are there ones that could add in extra data points from archival data?
# * Can then match back to HipTyc dataFrame to get final catalogue of observed targets.

# %%
spitzer['Tgt'], spitzer['Scrap'] = zip(*spitzer['Search_Tgt'].apply(lambda x: x.split(' ', 1)))
del spitzer['Scrap']
del spitzer['Search_Tgt']
s = spitzer.groupby(['Tgt'])
len(s)
# Out:
# 70

# %% [markdown]
# ## Total number of HipTyc stars observed by Spitzer in any program = 70

# %%
wlf_obs = spitzer.loc[spitzer['PI']=='Freedman, Wendy']
kvj_obs = spitzer.loc[spitzer['PI']=='Johnston, Kathryn V']

# %%
wlf_targets = wlf_obs.groupby(['Tgt'])
n_wlf = len(wlf_targets.groups)
kvj_targets = kvj_obs.groupby(['Tgt'])
n_kvj = len(kvj_targets.groups)
n_wlf, n_kvj
# Out:
# (51, 0)

# %% [markdown]
# ## Number of HipTyc stars observed by CRRP: 51
# ## Number of HipTyc stars observed by SMHASH: 0

# %% [markdown]
# # Which stars were observed by CRRP?
#
# * Need to drop duplicates in the row index from the wlf_obs dataFrame, then match to hiptyc dataFrame

# %%
wlf_obs['Search_Tgt_2'] = wlf_obs.Tgt
wlf_obs = wlf_obs.drop_duplicates(cols='Search_Tgt_2', take_last=True)
del wlf_obs['Search_Tgt_2']
wlf_obs.sort_index(inplace=True)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## The following table lists the fields that contain Hipparcos or Tycho RR Lyrae variables.
#
# **Note:** There is an LMC field in here. It was a 2s exposure, so the RRL is probably not saturated.
#
# The relavent fields here are Target_name, progid, and PI if you want to look up the data. AOR label is only going to give you that specific epoch. Every star in this list has at least 24 epochs.

# %%
wlf_obs
# Out:
#      Target_name   RA(J2000)  Dec(J2000) Instrument/Mode    AORKEY  \
# 23        RU_Scl    0.700000  -24.945278     IRAC Map PC  47397632
# 47        SW_And    5.929167   29.400833     IRAC Map PC  47218688
# 72        RU_Psc   18.608333   24.415556     IRAC Map PC  47402496
# 96        XX_And   19.362500   38.950556     IRAC Map PC  47421696
# 123       AM_Tuc   19.625000  -67.917778     IRAC Map PC  47590656
# 147       RR_Cet   23.033333    1.341667     IRAC Map PC  47285248
# 171       SV_Scl   26.245833  -30.059167     IRAC Map PC  47486464
# 195       CS_Eri   39.270833  -42.963333     IRAC Map PC  47338496
# 219        X_Ari   47.125000   10.445833     IRAC Map PC  47330816
# 243       SV_Eri   47.966667  -11.353889     IRAC Map PC  47446272
# 287       RX_Eri   72.433333  -15.741111     IRAC Map PC  47375360
# 311       RR_Gem  110.387500   30.883056     IRAC Map PC  47450368
# 344       HK_Pup  116.191667  -13.098889     IRAC Map PC  47418368
# 368       UY_Cam  119.741667   72.787500     IRAC Map PC  47427584
# 392       TT_Lyn  135.779167   44.585556     IRAC Map PC  47450112
# 418        T_Sex  148.366667    2.057222     IRAC Map PC  47325696
# 442       RR_Leo  151.929167   23.991667     IRAC Map PC  47431168
# 466       WY_Ant  154.016667  -29.728333     IRAC Map PC  47478784
# 490       TU_Uma  172.450000   30.067222     IRAC Map PC  47454720
# 515       SU_Dra  174.483333   67.329722     IRAC Map PC  47195136
# 539       BX_Leo  174.508333   16.543333     IRAC Map PC  47275264
# 563       UU_Vir  182.145833   -0.456667     IRAC Map PC  47353600
# 600       AB_Uma  182.808333   47.828611     IRAC Map PC  48979712
# 629       SW_Dra  184.441667   69.510556     IRAC Map PC  47461888
# 653       SV_Hya  187.625000  -26.047500     IRAC Map PC  47360768
# 677       SX_Uma  201.554167   56.256944     IRAC Map PC  47353344
# 701       RV_Uma  203.325000   53.987222     IRAC Map PC  47255040
# 727       ST_CVn  209.391667   29.857778     IRAC Map PC  47421952
# 752       UY_Boo  209.691667   12.951667     IRAC Map PC  47336960
# 776       TV_Boo  214.150000   42.359722     IRAC Map PC  47482112
# 800       AP_Ser  228.500000    9.980833     IRAC Map PC  47389696
# 825       ST_Boo  232.662500   35.784444     IRAC Map PC  47406080
# 850       AN_Ser  238.379167   12.961111     IRAC Map PC  47466240
# 874       RV_CrB  244.854167   29.713056     IRAC Map PC  47229696
# 899       VX_Her  247.666667   18.366667     IRAC Map PC  47463936
# 942       UV_Oct  248.104167  -83.902778     IRAC Map PC  48819968
# 970       TW_Her  268.629167   30.410278     IRAC Map PC  47317248
# 1018    V675_Sgr  273.395833  -34.316944     IRAC Map PC  47386112
# 1042      MT_Tel  285.550000  -46.653333     IRAC Map PC  47442176
# 1068      RR_Lyr  291.362500   42.784167     IRAC Map PC  47592960
# 1095    V440_Sgr  293.083333  -23.853333     IRAC Map PC  47332352
# 1119      XZ_Cyg  293.120833   56.388056     IRAC Map PC  47471616
# 1145      DX_Del  311.866667   12.463889     IRAC Map PC  47592448
# 1169      UY_Cyg  314.116667   30.427778     IRAC Map PC  47484160
# 1195       V_Ind  317.870833  -45.074444     IRAC Map PC  47401216
# 1232      YZ_Cap  319.883333  -15.116944     IRAC Map PC  47760640
# 1256      AV_Peg  328.008333   22.574722     IRAC Map PC  47399680
# 1301      DH_Peg  333.854167    6.822500     IRAC Map PC  47756544
# 1435      RZ_Cep  339.804167   64.858333     IRAC Map PC  47354624
# 1459      BH_Peg  343.254167   15.787778     IRAC Map PC  47313920
# 1492     HV00882   74.916667  -69.456111     IRAC Map PC  32246272
#
#                 AOR_label  progid               PI             Tgt
# 23         RU_Scl_epoch14   90002  Freedman, Wendy   0h02m48.0749s
# 47         SW_And_epoch16   90002  Freedman, Wendy   0h23m43.0939s
# 72         RU_Psc_epoch22   90002  Freedman, Wendy   1h14m25.9772s
# 96          XX_And_epoch1   90002  Freedman, Wendy   1h17m27.3702s
# 123     AM_Tuc_epoch1 xc1   90002  Freedman, Wendy   1h18m30.6120s
# 147        RR_Cet_epoch12   90002  Freedman, Wendy   1h32m08.1665s
# 171        SV_Scl_epoch24   90002  Freedman, Wendy   1h44m59.6640s
# 195         CS_Eri_epoch8   90002  Freedman, Wendy   2h37m05.6827s
# 219          X_Ari_epoch5   90002  Freedman, Wendy   3h08m30.8450s
# 243        SV_Eri_epoch16   90002  Freedman, Wendy   3h11m52.0990s
# 287         RX_Eri_epoch4   90002  Freedman, Wendy   4h49m44.3005s
# 311        RR_Gem_epoch24   90002  Freedman, Wendy   7h21m33.5303s
# 344        HK_Pup_epoch14   90002  Freedman, Wendy   7h44m46.7908s
# 368         UY_Cam_epoch5   90002  Freedman, Wendy   7h58m58.8867s
# 392         TT_Lyn_epoch1   90002  Freedman, Wendy   9h03m07.8552s
# 418         T_Sex_epoch15   90002  Freedman, Wendy   9h53m28.4106s
# 442         RR_Leo_epoch9   90002  Freedman, Wendy  10h07m43.4692s
# 466         WY_Ant_epoch3   90002  Freedman, Wendy  10h16m04.9219s
# 490        TU_Uma_epoch19   90002  Freedman, Wendy  11h29m48.5376s
# 515        SU_Dra_epoch10   90002  Freedman, Wendy  11h37m56.6785s
# 539         BX_Leo_epoch9   90002  Freedman, Wendy  11h38m02.0801s
# 563        UU_Vir_epoch19   90002  Freedman, Wendy  12h08m35.0976s
# 600     AB_Uma_epoch1 xc9   90002  Freedman, Wendy  12h11m14.6045s
# 629        SW_Dra_epoch14   90002  Freedman, Wendy  12h17m46.6736s
# 653        SV_Hya_epoch17   90002  Freedman, Wendy  12h30m30.5274s
# 677         SX_Uma_epoch3   90002  Freedman, Wendy  13h26m13.5315s
# 701         RV_Uma_epoch7   90002  Freedman, Wendy  13h33m18.1091s
# 727         ST_CVn_epoch9   90002  Freedman, Wendy  13h57m34.0723s
# 752         UY_Boo_epoch1   90002  Freedman, Wendy  13h58m46.3367s
# 776         TV_Boo_epoch4   90002  Freedman, Wendy  14h16m36.5845s
# 800        AP_Ser_epoch20   90002  Freedman, Wendy  15h14m00.9448s
# 825         ST_Boo_epoch4   90002  Freedman, Wendy  15h30m39.2432s
# 850        AN_Ser_epoch22   90002  Freedman, Wendy  15h53m31.0547s
# 874        RV_CrB_epoch10   90002  Freedman, Wendy  16h19m25.8691s
# 899        VX_Her_epoch16   90002  Freedman, Wendy  16h30m40.8325s
# 942     UV_Oct_epoch1 xc7   90002  Freedman, Wendy  16h32m25.8508s
# 970         TW_Her_epoch4   90002  Freedman, Wendy  17h54m31.2012s
# 1018     V675_Sgr_epoch21   90002  Freedman, Wendy  18h13m35.3906s
# 1042        MT_Tel_epoch8   90002  Freedman, Wendy  19h02m12.3999s
# 1068    RR_Lyr_epoch1 xc2   90002  Freedman, Wendy  19h25m28.0005s
# 1095     V440_Sgr_epoch23   90002  Freedman, Wendy  19h32m20.7861s
# 1119       XZ_Cyg_epoch16   90002  Freedman, Wendy  19h32m29.2163s
# 1145    DX_Del_epoch1 xc2   90002  Freedman, Wendy  20h47m28.3447s
# 1169       UY_Cyg_epoch15   90002  Freedman, Wendy  20h56m28.3081s
# 1195         V_Ind_epoch9   90002  Freedman, Wendy  21h11m29.9634s
# 1232    YZ_Cap_epoch1 xc5   90002  Freedman, Wendy  21h19m32.4243s
# 1256        AV_Peg_epoch6   90002  Freedman, Wendy  21h52m02.7832s
# 1301    DH_Peg_epoch1 xc8   90002  Freedman, Wendy  22h15m25.6274s
# 1435        RZ_Cep_epoch9   90002  Freedman, Wendy  22h39m13.0518s
# 1459       BH_Peg_epoch10   90002  Freedman, Wendy  22h53m01.0547s
# 1492  LMC HV00882 epoch18   61005  Freedman, Wendy   4h59m13.5718s

# %% [markdown]
# Now will do a check to see what has been observed by other programs

# %%
other_obs = spitzer.loc[spitzer['PI']!='Freedman, Wendy'] ## Any observer except Wendy

# %%
other_targets = other_obs.groupby(['Tgt'])
n_other = len(other_targets.groups)
n_other
# Out:
# 24

# %% [markdown]
# ## Total of 24 RRL in HipTyc that have been observed by other programs, but NOT by us.

# %%
other_obs['Search_Tgt_2'] = other_obs.Tgt
other_obs = other_obs.drop_duplicates(cols='Search_Tgt_2', take_last=True)
del other_obs['Search_Tgt_2']
other_obs.sort_index(inplace=True)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
other_obs
# Out:
#                   Target_name   RA(J2000)  Dec(J2000) Instrument/Mode  \
# 48         U20027_2M0033-1521    8.349417  -15.358583        IRAC Map
# 394                    DLS-L1  140.216667   30.000000        IRAC Map
# 491   SDSSJ113246.50+120901.7  173.193750   12.150556        IRAC Map
# 614                   NGC4236  184.175417   69.462778        IRAC Map
# 703                   NGC5311  207.233750   39.985250     IRAC Map PC
# 728                 Bootes II  209.500000   12.850000     IRAC Map PC
# 801     RXJ1518.9-4050 - clus  229.720000  -40.848056        IRAC Map
# 826                    NN Ser  238.234167   12.913111        IRAC Map
# 875           SDSS J1619+4526  244.992708   45.442000        IRAC Map
# 946          357.13525GLIMPSE  264.672590  -31.378248        IRAC Map
# 1071             Kepler14-1-1  292.765220   42.080201     IRAC Map PC
# 1171          90.89286GLIMPSE  315.768807   50.864762     IRAC Map PC
# 1257              WISE2155-82  328.822678  -82.870741     IRAC Map PC
# 1462         147.88094GLIMPSE   60.564211   55.253970     IRAC Map PC
# 1464                  STRIP-4   70.838860  -53.599236     IRAC Map PC
# 1468                      LMC   73.689875  -69.859947        IRAC Map
# 1493                 NGC 6701  280.801917   60.653333     IRAC Map PC
# 1494                 HIP90954  278.310777   40.159634     IRAC Map PC
# 1495                 UGC12519  350.011542   15.952750        IRAC Map
# 1498         353.33766GLIMPSE  262.206308  -34.563099        IRAC Map
# 1506             SSPT.gaps.23  347.741667  -58.183333     IRAC Map PC
# 1507                   SSPT67    1.145833  -58.583333     IRAC Map PC
# 1508  2MASS J12364811-0219180  189.200458   -2.321667        IRAC Map
# 1517            SSPT03_09_FCO  349.791667  -53.808333     IRAC Map PC
#
#         AORKEY                                AOR_label  progid  \
# 48    22138368               IRAC-30-U20027_2M0033-1521     284
# 394   17645312                                   DLS-L1   30478
# 491   23767552                          IRACfour - 0016   40517
# 614    5504768                           IRAC-N4236 - A     159
# 703   31088640                             S4G-NGC5311B   61063
# 728   42317568                  IRACPC-0000 - Bootes II   80063
# 801    5666048  EVANS-WTTS-IRAC - RXJ1518.9-4050 - clus     173
# 826   17725696                               NNSer_irac   30070
# 875   26694912                                IRAC-0005   50681
# 946   14326272             l357.13525-00.01535.20050929   20201
# 1071  50111744                        Kepler 14 - edge1   10067
# 1171  37883392             l090.89286+02.78000.20090903   60020
# 1257  41048832            Ch1&2 (epoch 1) - WISE2155-82   70062
# 1462  32840192             l147.88094+01.91000.20091005   61070
# 1464  44636672                               STRIP-1st4   80039
# 1468  14365696                           IRAC-map2-0201   20203
# 1493  42384640                           NGC6701_100_14   80089
# 1494  40646144                IRACPC-Sample1 - HIP90954   70076
# 1495  17404416                            IRAC-UGC12519   30348
# 1498  14322432             l353.33766-00.01035.20050929   20201
# 1506  47014656                             SSPT.gaps.23   80096
# 1507  47593216                                   SSPT67   80096
# 1508  13778432                 IRAC - 4 filters, copy 3     244
# 1517  43968256                               SSPT03_09a   80096
#
#                          PI             Tgt
# 48              Cruz, Kelle   0h33m38.2963s
# 394         Fazio, Giovanni   9h19m06.0352s
# 491     Meisenheimer, Klaus  11h33m03.7646s
# 614       Kennicutt, Robert  12h17m46.6736s
# 703           Sheth, Kartik  13h48m15.9375s
# 728         Boyer, Martha L  13h58m46.3367s
# 801             Evans, Neal  15h22m25.3857s
# 826   Brinkworth, Carolyn S  15h53m31.0547s
# 875            Fan, Xiaohui  16h20m04.0796s
# 946          Churchwell, Ed  17h40m48.4790s
# 1071        Werner, Michael  19h25m28.0005s
# 1171     Whitney, Barbara A  21h04m32.9224s
# 1257    Kirkpatrick, J.Davy  21h53m35.3613s
# 1462     Whitney, Barbara A   4h06m38.8898s
# 1464      Scarlata, Claudia   4h48m13.2935s
# 1468      Meixner, Margaret   4h59m13.5718s
# 1493       Sanders, David B  18h44m04.6069s
# 1494               Su, Kate  18h33m15.2270s
# 1495          Rieke, George  23h20m07.0313s
# 1498         Churchwell, Ed  17h35m05.8228s
# 1506      Stanford, Spencer  23h11m00.5640s
# 1507      Stanford, Spencer   0h04m06.3430s
# 1508      Metchev, Stanimir  12h36m27.3230s
# 1517      Stanford, Spencer  23h23m57.4146s

# %%
RA_Dec = SkyCoord(ra=(hiptyc.RA)*u.degree, dec=(hiptyc.Dec)*u.degree, frame='icrs')

# %%
hiptyc = hiptyc.assign(ra_hours = lambda x: (RA_Dec.ra.to_string('h')))

# %%
wlf_obs = wlf_obs.assign(Target_name = lambda x: (x.Target_name.str.replace('_', '')))

# %%
wlf_obs
# Out:
#      Target_name   RA(J2000)  Dec(J2000) Instrument/Mode    AORKEY  \
# 23         RUScl    0.700000  -24.945278     IRAC Map PC  47397632
# 47         SWAnd    5.929167   29.400833     IRAC Map PC  47218688
# 72         RUPsc   18.608333   24.415556     IRAC Map PC  47402496
# 96         XXAnd   19.362500   38.950556     IRAC Map PC  47421696
# 123        AMTuc   19.625000  -67.917778     IRAC Map PC  47590656
# 147        RRCet   23.033333    1.341667     IRAC Map PC  47285248
# 171        SVScl   26.245833  -30.059167     IRAC Map PC  47486464
# 195        CSEri   39.270833  -42.963333     IRAC Map PC  47338496
# 219         XAri   47.125000   10.445833     IRAC Map PC  47330816
# 243        SVEri   47.966667  -11.353889     IRAC Map PC  47446272
# 287        RXEri   72.433333  -15.741111     IRAC Map PC  47375360
# 311        RRGem  110.387500   30.883056     IRAC Map PC  47450368
# 344        HKPup  116.191667  -13.098889     IRAC Map PC  47418368
# 368        UYCam  119.741667   72.787500     IRAC Map PC  47427584
# 392        TTLyn  135.779167   44.585556     IRAC Map PC  47450112
# 418         TSex  148.366667    2.057222     IRAC Map PC  47325696
# 442        RRLeo  151.929167   23.991667     IRAC Map PC  47431168
# 466        WYAnt  154.016667  -29.728333     IRAC Map PC  47478784
# 490        TUUma  172.450000   30.067222     IRAC Map PC  47454720
# 515        SUDra  174.483333   67.329722     IRAC Map PC  47195136
# 539        BXLeo  174.508333   16.543333     IRAC Map PC  47275264
# 563        UUVir  182.145833   -0.456667     IRAC Map PC  47353600
# 600        ABUma  182.808333   47.828611     IRAC Map PC  48979712
# 629        SWDra  184.441667   69.510556     IRAC Map PC  47461888
# 653        SVHya  187.625000  -26.047500     IRAC Map PC  47360768
# 677        SXUma  201.554167   56.256944     IRAC Map PC  47353344
# 701        RVUma  203.325000   53.987222     IRAC Map PC  47255040
# 727        STCVn  209.391667   29.857778     IRAC Map PC  47421952
# 752        UYBoo  209.691667   12.951667     IRAC Map PC  47336960
# 776        TVBoo  214.150000   42.359722     IRAC Map PC  47482112
# 800        APSer  228.500000    9.980833     IRAC Map PC  47389696
# 825        STBoo  232.662500   35.784444     IRAC Map PC  47406080
# 850        ANSer  238.379167   12.961111     IRAC Map PC  47466240
# 874        RVCrB  244.854167   29.713056     IRAC Map PC  47229696
# 899        VXHer  247.666667   18.366667     IRAC Map PC  47463936
# 942        UVOct  248.104167  -83.902778     IRAC Map PC  48819968
# 970        TWHer  268.629167   30.410278     IRAC Map PC  47317248
# 1018     V675Sgr  273.395833  -34.316944     IRAC Map PC  47386112
# 1042       MTTel  285.550000  -46.653333     IRAC Map PC  47442176
# 1068       RRLyr  291.362500   42.784167     IRAC Map PC  47592960
# 1095     V440Sgr  293.083333  -23.853333     IRAC Map PC  47332352
# 1119       XZCyg  293.120833   56.388056     IRAC Map PC  47471616
# 1145       DXDel  311.866667   12.463889     IRAC Map PC  47592448
# 1169       UYCyg  314.116667   30.427778     IRAC Map PC  47484160
# 1195        VInd  317.870833  -45.074444     IRAC Map PC  47401216
# 1232       YZCap  319.883333  -15.116944     IRAC Map PC  47760640
# 1256       AVPeg  328.008333   22.574722     IRAC Map PC  47399680
# 1301       DHPeg  333.854167    6.822500     IRAC Map PC  47756544
# 1435       RZCep  339.804167   64.858333     IRAC Map PC  47354624
# 1459       BHPeg  343.254167   15.787778     IRAC Map PC  47313920
# 1492     HV00882   74.916667  -69.456111     IRAC Map PC  32246272
#
#                 AOR_label  progid               PI             Tgt
# 23         RU_Scl_epoch14   90002  Freedman, Wendy   0h02m48.0749s
# 47         SW_And_epoch16   90002  Freedman, Wendy   0h23m43.0939s
# 72         RU_Psc_epoch22   90002  Freedman, Wendy   1h14m25.9772s
# 96          XX_And_epoch1   90002  Freedman, Wendy   1h17m27.3702s
# 123     AM_Tuc_epoch1 xc1   90002  Freedman, Wendy   1h18m30.6120s
# 147        RR_Cet_epoch12   90002  Freedman, Wendy   1h32m08.1665s
# 171        SV_Scl_epoch24   90002  Freedman, Wendy   1h44m59.6640s
# 195         CS_Eri_epoch8   90002  Freedman, Wendy   2h37m05.6827s
# 219          X_Ari_epoch5   90002  Freedman, Wendy   3h08m30.8450s
# 243        SV_Eri_epoch16   90002  Freedman, Wendy   3h11m52.0990s
# 287         RX_Eri_epoch4   90002  Freedman, Wendy   4h49m44.3005s
# 311        RR_Gem_epoch24   90002  Freedman, Wendy   7h21m33.5303s
# 344        HK_Pup_epoch14   90002  Freedman, Wendy   7h44m46.7908s
# 368         UY_Cam_epoch5   90002  Freedman, Wendy   7h58m58.8867s
# 392         TT_Lyn_epoch1   90002  Freedman, Wendy   9h03m07.8552s
# 418         T_Sex_epoch15   90002  Freedman, Wendy   9h53m28.4106s
# 442         RR_Leo_epoch9   90002  Freedman, Wendy  10h07m43.4692s
# 466         WY_Ant_epoch3   90002  Freedman, Wendy  10h16m04.9219s
# 490        TU_Uma_epoch19   90002  Freedman, Wendy  11h29m48.5376s
# 515        SU_Dra_epoch10   90002  Freedman, Wendy  11h37m56.6785s
# 539         BX_Leo_epoch9   90002  Freedman, Wendy  11h38m02.0801s
# 563        UU_Vir_epoch19   90002  Freedman, Wendy  12h08m35.0976s
# 600     AB_Uma_epoch1 xc9   90002  Freedman, Wendy  12h11m14.6045s
# 629        SW_Dra_epoch14   90002  Freedman, Wendy  12h17m46.6736s
# 653        SV_Hya_epoch17   90002  Freedman, Wendy  12h30m30.5274s
# 677         SX_Uma_epoch3   90002  Freedman, Wendy  13h26m13.5315s
# 701         RV_Uma_epoch7   90002  Freedman, Wendy  13h33m18.1091s
# 727         ST_CVn_epoch9   90002  Freedman, Wendy  13h57m34.0723s
# 752         UY_Boo_epoch1   90002  Freedman, Wendy  13h58m46.3367s
# 776         TV_Boo_epoch4   90002  Freedman, Wendy  14h16m36.5845s
# 800        AP_Ser_epoch20   90002  Freedman, Wendy  15h14m00.9448s
# 825         ST_Boo_epoch4   90002  Freedman, Wendy  15h30m39.2432s
# 850        AN_Ser_epoch22   90002  Freedman, Wendy  15h53m31.0547s
# 874        RV_CrB_epoch10   90002  Freedman, Wendy  16h19m25.8691s
# 899        VX_Her_epoch16   90002  Freedman, Wendy  16h30m40.8325s
# 942     UV_Oct_epoch1 xc7   90002  Freedman, Wendy  16h32m25.8508s
# 970         TW_Her_epoch4   90002  Freedman, Wendy  17h54m31.2012s
# 1018     V675_Sgr_epoch21   90002  Freedman, Wendy  18h13m35.3906s
# 1042        MT_Tel_epoch8   90002  Freedman, Wendy  19h02m12.3999s
# 1068    RR_Lyr_epoch1 xc2   90002  Freedman, Wendy  19h25m28.0005s
# 1095     V440_Sgr_epoch23   90002  Freedman, Wendy  19h32m20.7861s
# 1119       XZ_Cyg_epoch16   90002  Freedman, Wendy  19h32m29.2163s
# 1145    DX_Del_epoch1 xc2   90002  Freedman, Wendy  20h47m28.3447s
# 1169       UY_Cyg_epoch15   90002  Freedman, Wendy  20h56m28.3081s
# 1195         V_Ind_epoch9   90002  Freedman, Wendy  21h11m29.9634s
# 1232    YZ_Cap_epoch1 xc5   90002  Freedman, Wendy  21h19m32.4243s
# 1256        AV_Peg_epoch6   90002  Freedman, Wendy  21h52m02.7832s
# 1301    DH_Peg_epoch1 xc8   90002  Freedman, Wendy  22h15m25.6274s
# 1435        RZ_Cep_epoch9   90002  Freedman, Wendy  22h39m13.0518s
# 1459       BH_Peg_epoch10   90002  Freedman, Wendy  22h53m01.0547s
# 1492  LMC HV00882 epoch18   61005  Freedman, Wendy   4h59m13.5718s

# %%
spitzer_tycho_ipac = Table.read('tycho_obs_by_spitzer.ipac', format='ipac')

# %%
spitzer_tycho = spitzer_tycho_ipac.to_pandas()

# %%
spitzer_tycho.head()
# Out:
#                     Search_Tgt           Target_name  RA(J2000)  Dec(J2000)  \
# 0  4h06m38.8898s 4h06m38.8898s  l148.44527d+1.89767d  60.776678   55.498143
# 1  4h06m38.8898s 4h06m38.8898s  l148.86493d+2.22832d  60.811094   55.387048
# 2  4h06m38.8898s 4h06m38.8898s      147.88094GLIMPSE  60.564211   55.253970
# 3  4h48m13.2935s 4h48m13.2935s              STRIP-s4  71.138863  -53.599236
# 4  4h48m13.2935s 4h48m13.2935s               STRIP-4  70.838860  -53.599236
#
#   Instrument/Mode    AORKEY  progid                  PI
# 0     IRAC Map PC  40059392   70072  Whitney, Barbara A
# 1     IRAC Map PC  40065536   70072  Whitney, Barbara A
# 2     IRAC Map PC  32840192   61070  Whitney, Barbara A
# 3     IRAC Map PC  44634880   80039   Scarlata, Claudia
# 4     IRAC Map PC  44636672   80039   Scarlata, Claudia

# %% [markdown]
# # Predicted TGAS RRL

# %% [markdown]
# * TGAS will release Gaia obs for the Tycho stars in Summer 2016
# * How many of the Tycho RRL (i.e. early release Gaia stars) do we have in CRRP/SMHASH?

# %%
spitzer_tycho['Tgt'], spitzer_tycho['Scrap'] = zip(*spitzer_tycho['Search_Tgt'].apply(lambda x: x.split(' ', 1)))
del spitzer_tycho['Scrap']
del spitzer_tycho['Search_Tgt']
s = spitzer_tycho.groupby(['Tgt'])
len(s)
# Out:
# 11

# %%
wlf_obs_tycho = spitzer_tycho.loc[spitzer_tycho['PI']=='Freedman, Wendy']
kvj_obs_tycho = spitzer_tycho.loc[spitzer_tycho['PI']=='Johnston, Kathryn V']

# %%
wlf_obs_tycho['Search_Tgt_2'] = wlf_obs_tycho.Tgt
wlf_obs_tycho = wlf_obs_tycho.drop_duplicates(cols='Search_Tgt_2', take_last=True)
del wlf_obs_tycho['Search_Tgt_2']
wlf_obs_tycho.sort_index(inplace=True)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   from ipykernel import kernelapp as app

# %%
wlf_obs_tycho
# Out:
#    Target_name  RA(J2000)  Dec(J2000) Instrument/Mode    AORKEY  progid  \
# 32     HV00882  74.916667  -69.456111     IRAC Map PC  32248576   61005
#
#                  PI            Tgt
# 32  Freedman, Wendy  4h59m13.5718s

# %% [markdown]
# ## CHP observed 1 field with a tycho RRL in it :(
#
# * There are 10 other fields containing tycho RRL in the Spitzer archive, but there isn't time resolution

# %%
spitzer_tycho
# Out:
#                 Target_name   RA(J2000)  Dec(J2000) Instrument/Mode    AORKEY  \
# 0      l148.44527d+1.89767d   60.776678   55.498143     IRAC Map PC  40059392
# 1      l148.86493d+2.22832d   60.811094   55.387048     IRAC Map PC  40065536
# 2          147.88094GLIMPSE   60.564211   55.253970     IRAC Map PC  32840192
# 3                  STRIP-s4   71.138863  -53.599236     IRAC Map PC  44634880
# 4                   STRIP-4   70.838860  -53.599236     IRAC Map PC  44636672
# 5                       LMC   73.974292  -69.992303        IRAC Map  14353152
# 6                       LMC   75.579708  -69.089531        IRAC Map  14353408
# 7                       LMC   73.689875  -69.859947        IRAC Map  14365696
# 8                       LMC   75.620208  -68.998842        IRAC Map  14365952
# 9                   HV00882   74.916667  -69.456111     IRAC Map PC  32230144
# 10                  HV00882   74.916667  -69.456111     IRAC Map PC  32228096
# 11                  HV00882   74.916667  -69.456111     IRAC Map PC  32226816
# 12                  HV00882   74.916667  -69.456111     IRAC Map PC  32229632
# 13                  HV00882   74.916667  -69.456111     IRAC Map PC  32229120
# 14                  HV00882   74.916667  -69.456111     IRAC Map PC  32227584
# 15                  HV00882   74.916667  -69.456111     IRAC Map PC  32227328
# 16                  HV00882   74.916667  -69.456111     IRAC Map PC  32242944
# 17                  HV00882   74.916667  -69.456111     IRAC Map PC  32242432
# 18                  HV00882   74.916667  -69.456111     IRAC Map PC  32243456
# 19                  HV00882   74.916667  -69.456111     IRAC Map PC  32241920
# 20                  HV00882   74.916667  -69.456111     IRAC Map PC  32227840
# 21                  HV00882   74.916667  -69.456111     IRAC Map PC  32228608
# 22                  HV00882   74.916667  -69.456111     IRAC Map PC  32247808
# 23                  HV00882   74.916667  -69.456111     IRAC Map PC  32250112
# 24                  HV00882   74.916667  -69.456111     IRAC Map PC  32252416
# 25                  HV00882   74.916667  -69.456111     IRAC Map PC  32245504
# 26                  HV00882   74.916667  -69.456111     IRAC Map PC  32243968
# 27                  HV00882   74.916667  -69.456111     IRAC Map PC  32247040
# 28                  HV00882   74.916667  -69.456111     IRAC Map PC  32246272
# 29                  HV00882   74.916667  -69.456111     IRAC Map PC  32249344
# 30                  HV00882   74.916667  -69.456111     IRAC Map PC  32251648
# 31                  HV00882   74.916667  -69.456111     IRAC Map PC  32250880
# 32                  HV00882   74.916667  -69.456111     IRAC Map PC  32248576
# 33                 NGC 6701  280.801917   60.653333     IRAC Map PC  42384640
# 34                 HIP90954  278.310777   40.159634     IRAC Map PC  40646144
# 35                 UGC12519  350.011542   15.952750        IRAC Map  17404416
# 36         353.71481GLIMPSE  262.458757  -34.248679        IRAC Map  14322688
# 37         353.74766GLIMPSE  262.477923  -34.219775        IRAC Map  14292736
# 38         353.33766GLIMPSE  262.206308  -34.563099        IRAC Map  14322432
# 39   SPT-23_CL19_J2312-5820  347.998000  -58.340000     IRAC Map PC  37092096
# 40                   SSPT32  346.958333  -59.116667     IRAC Map PC  45491968
# 41                   SSPT33  349.270833  -58.154167     IRAC Map PC  45490688
# 42                   SSPT32  346.958333  -59.116667     IRAC Map PC  45491712
# 43                   SSPT32  346.958333  -59.116667     IRAC Map PC  45492480
# 44                   SSPT32  346.958333  -59.116667     IRAC Map PC  45492224
# 45                   SSPT33  349.270833  -58.154167     IRAC Map PC  45490944
# 46             SSPT.gaps.23  347.741667  -58.183333     IRAC Map PC  47014656
# 47                   SSPT67    1.145833  -58.583333     IRAC Map PC  47593216
# 48  2MASS J12364811-0219180  189.200458   -2.321667        IRAC Map  13778432
# 49                 SBCS4_06  351.210417  -53.375000     IRAC Map PC  42609920
# 50             SBCS4_06_FCO  351.210417  -53.375000     IRAC Map PC  42609408
# 51            SBCS2323-5258  350.868750  -52.978278        IRAC Map  23880704
# 52            SBCS2325-5302  351.341667  -53.041111        IRAC Map  23876608
# 53            SBCS2324-5258  351.202083  -52.982278        IRAC Map  23871232
# 54            SBCS2322-5337  350.595000  -53.619000        IRAC Map  23868160
# 55            SBCS2321-5333  350.454583  -53.560167        IRAC Map  23872000
# 56            SSPT03_09_FCO  349.791667  -53.808333     IRAC Map PC  43968256
# 57            SSPT03_09_FCO  349.791667  -53.808333     IRAC Map PC  43968000
#
#     progid                  PI             Tgt
# 0    70072  Whitney, Barbara A   4h06m38.8898s
# 1    70072  Whitney, Barbara A   4h06m38.8898s
# 2    61070  Whitney, Barbara A   4h06m38.8898s
# 3    80039   Scarlata, Claudia   4h48m13.2935s
# 4    80039   Scarlata, Claudia   4h48m13.2935s
# 5    20203   Meixner, Margaret   4h59m13.5718s
# 6    20203   Meixner, Margaret   4h59m13.5718s
# 7    20203   Meixner, Margaret   4h59m13.5718s
# 8    20203   Meixner, Margaret   4h59m13.5718s
# 9    61005     Freedman, Wendy   4h59m13.5718s
# 10   61005     Freedman, Wendy   4h59m13.5718s
# 11   61005     Freedman, Wendy   4h59m13.5718s
# 12   61005     Freedman, Wendy   4h59m13.5718s
# 13   61005     Freedman, Wendy   4h59m13.5718s
# 14   61005     Freedman, Wendy   4h59m13.5718s
# 15   61005     Freedman, Wendy   4h59m13.5718s
# 16   61005     Freedman, Wendy   4h59m13.5718s
# 17   61005     Freedman, Wendy   4h59m13.5718s
# 18   61005     Freedman, Wendy   4h59m13.5718s
# 19   61005     Freedman, Wendy   4h59m13.5718s
# 20   61005     Freedman, Wendy   4h59m13.5718s
# 21   61005     Freedman, Wendy   4h59m13.5718s
# 22   61005     Freedman, Wendy   4h59m13.5718s
# 23   61005     Freedman, Wendy   4h59m13.5718s
# 24   61005     Freedman, Wendy   4h59m13.5718s
# 25   61005     Freedman, Wendy   4h59m13.5718s
# 26   61005     Freedman, Wendy   4h59m13.5718s
# 27   61005     Freedman, Wendy   4h59m13.5718s
# 28   61005     Freedman, Wendy   4h59m13.5718s
# 29   61005     Freedman, Wendy   4h59m13.5718s
# 30   61005     Freedman, Wendy   4h59m13.5718s
# 31   61005     Freedman, Wendy   4h59m13.5718s
# 32   61005     Freedman, Wendy   4h59m13.5718s
# 33   80089    Sanders, David B  18h44m04.6069s
# 34   70076            Su, Kate  18h33m15.2270s
# 35   30348       Rieke, George  23h20m07.0313s
# 36   20201      Churchwell, Ed  17h35m05.8228s
# 37   20201      Churchwell, Ed  17h35m05.8228s
# 38   20201      Churchwell, Ed  17h35m05.8228s
# 39   60099       Brodwin, Mark  23h11m00.5640s
# 40   80096   Stanford, Spencer  23h11m00.5640s
# 41   80096   Stanford, Spencer  23h11m00.5640s
# 42   80096   Stanford, Spencer  23h11m00.5640s
# 43   80096   Stanford, Spencer  23h11m00.5640s
# 44   80096   Stanford, Spencer  23h11m00.5640s
# 45   80096   Stanford, Spencer  23h11m00.5640s
# 46   80096   Stanford, Spencer  23h11m00.5640s
# 47   80096   Stanford, Spencer   0h04m06.3430s
# 48     244   Metchev, Stanimir  12h36m27.3230s
# 49   80096   Stanford, Spencer  23h23m57.4146s
# 50   80096   Stanford, Spencer  23h23m57.4146s
# 51   40370   Stanford, Spencer  23h23m57.4146s
# 52   40370   Stanford, Spencer  23h23m57.4146s
# 53   40370   Stanford, Spencer  23h23m57.4146s
# 54   40370   Stanford, Spencer  23h23m57.4146s
# 55   40370   Stanford, Spencer  23h23m57.4146s
# 56   80096   Stanford, Spencer  23h23m57.4146s
# 57   80096   Stanford, Spencer  23h23m57.4146s

# %% [markdown]
# # Conclusion: It is **NOT** worth waiting for TGAS to publish the CRRP calibration, although it may be worth doing another short paper with a comparison when the TGAS results come out *if* we have the 3.6 mags available.
